# %% [markdown]
# # Performance Analysis of PReFIL
#
# ---
#
#
# * Resources ~
#   * https://github.com/kushalkafle/PReFIL
#
# ---
#
# ### Table of contents ~
# #### 1. Creating the environment
# #### 2. Importing the pretrained weights
# #### 3. Evaluating the model
# #### 4. Computing performance metric

# %% [markdown]
# ## Creating the environment
# ---

# %%
# !git clone "https://github.com/kushalkafle/PReFIL"
# Out:
# Cloning into 'PReFIL'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 36 (delta 12), reused 24 (delta 5), pack-reused 0
# Unpacking objects: 100% (36/36), done.

# %% [markdown]
# #### Accelerating using CUDA

# %%
try: 
    import torch
except:
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())
    accelerator = 'cu80' if os.path.exists('/opt/bin/nvidia-smi') else 'cpu'
    # !pip install -q \
      http://download.pytorch.org/whl/{accelerator}/torch-0.4.1-{platform}-linux_x86_64.whl \
      torchvision

# %%
import torch
use_cuda = torch.cuda.is_available()
device = torch.device("cuda" if use_cuda else "cpu")

# %% [markdown]
# ## Importing the pretrained weights and dataset
#
#
# ---

# %%
# !bash /content/PReFIL/data/get_DVQA_data.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# images/bar_train_00010388.png
# images/bar_train_00040081.png
# images/bar_train_00089160.png
# images/bar_train_00154782.png
# images/bar_train_00148579.png
# images/bar_train_00145719.png
# images/bar_train_00017702.png
# images/bar_train_00175412.png
# images/bar_val_easy_00018690.png
# images/bar_train_00130767.png
# images/bar_val_easy_00015830.png
# images/bar_train_00106395.png
# images/bar_train_00103535.png
# images/bar_train_00092377.png
# images/bar_train_00065145.png
# images/bar_train_00002750.png
# images/bar_train_00160460.png
# images/bar_train_00050193.png
# images/bar_train_00020101.png
# images/bar_val_easy_00012026.png
# images/bar_train_00027814.png
# images/bar_train_00188384.png
# images/bar_train_00185524.png
# images/bar_val_easy_00025942.png
# images/bar_val_easy_00019739.png
# images/bar_train_00140879.png
# images/bar_train_00048025.png
# images/bar_train_00075257.png
# images/bar_train_00012862.png
# ...

# %%
# !bash /content/PReFIL/data/get_pretrained_models.sh
# Out:
# --2022-07-07 20:14:51--  https://docs.google.com/uc?export=download&confirm=t&id=1MMVtvhFCgDNdF4RalzRwlGMQ4D5qNqVE
# Resolving docs.google.com (docs.google.com)... 172.217.2.110, 2607:f8b0:4004:c19::8b, 2607:f8b0:4004:c19::64, ...
# Connecting to docs.google.com (docs.google.com)|172.217.2.110|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0g-0s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/irog0o90hig1dn5qj29jubqectt360ou/1657224825000/05028220109015226717/*/1MMVtvhFCgDNdF4RalzRwlGMQ4D5qNqVE?e=download&uuid=10bd4886-6e4c-4d49-8060-e1486a97b816 [following]
# ...
# --2022-07-07 20:14:51--  https://doc-0g-0s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/irog0o90hig1dn5qj29jubqectt360ou/1657224825000/05028220109015226717/*/1MMVtvhFCgDNdF4RalzRwlGMQ4D5qNqVE?e=download&uuid=10bd4886-6e4c-4d49-8060-e1486a97b816
# ...

# %% [markdown]
# ## Evaluating the model
#
#
# ---

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# #### Replace the required files with the modified ones given in the drive link

# %%
# !python /content/PReFIL/run_cqa.py --expt_name /content/experiments/DVQA_pretrained --evaluate
# Out:
# Building Dataloaders according to configuration
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Building model to train:
# Model Overview:
# PReFIL(
#   (rnn): QuestionEncoder(
#     (embedding): Embedding(227, 32)
#     (lstm): LSTM(32, 256)
#   )
#   (cnn): DenseNetEncoder(
#     (densenet): DenseNet(
#       (first_conv): Sequential(
#         (conv0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#         (norm0): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu0): ReLU(inplace=True)
# ...

# %% [markdown]
# ## Computing performance metric
#
#
# ---

# %%
# !python /content/PReFIL/compute_metrics.py --expt_name /content/experiments/DVQA_pretrained
# Out:
# Metrics for val_easy split
# 	Category: overall:
# 		Overall accuracy is: 96.9328
# 	Category: by_qtype:
# 		Accuracy for reasoning is: 96.5048
# 		Accuracy for data is: 96.4646
# 		Accuracy for structure is: 99.7739
# 	Category: by_imgtype:
# 		Accuracy for bar is: 96.9328
# Metrics for val_hard split
# 	Category: overall:
# 		Overall accuracy is: 96.9999
# 	Category: by_qtype:
# 		Accuracy for reasoning is: 96.5612
# 		Accuracy for data is: 96.632
# 		Accuracy for structure is: 99.624
# 	Category: by_imgtype:
# 		Accuracy for bar is: 96.9999

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
